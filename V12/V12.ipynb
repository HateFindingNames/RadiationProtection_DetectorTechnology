# %% [markdown]
# # Gammaspektrometrie mit NaJ-Szintillationszähler (LB 2045);Identifikation von Nukliden
# ----------------------------------

# %% [markdown]
# Links: http://www.physik-box.de/gamma1.html

# %% [markdown]
# ## NaJ(Tl)-Szintillationszähler
# Ein Szintillationszähler ist ein Instrument zur Detektion und Quantisierung im Sinne der Energiebestimmung von $\gamma$-Strahlung. Somit eignet er sich $\gamma$-Spektren aufzunehmen.
# ![alt text](referenzen/szintillationszaehler.jpg "Szintillationszähler")
# Quelle: Eichler, Kronfeldt, Sahm - "Das neue physikalische Grundpraktikum", 2016
#
# Im Bild gezeigt der schematische Aufbau bestehend aus Szintillator, Photomultiplier (**S**ekundär**e**lektronen**v**ervielfacher) und (Signal)Verstärker. Der Szintillator selbst besteht häufig aus einem mit Thallium dotierten Natriumjodid-Einkristall. Im Szintillator wird die ionisierende Wechselwirkung der einfallenden Gammas ausgenutzt. Über den Fotoeffekt löst ein Gamma-Quant im NaJ-Kristall ein Elektron aus, welches entweder mit höherer Wahrscheinlichkeit im Kristall selbst unter Wärmeentwicklung wieder absorbiert wird oder mit weniger Wahrscheinlichkeit mit einer der Thallium-Fehlstellen unter Aussendung eines Photons höherer Wellenlänge wieder rekombiniert. Die Anzahl der erzeugten Sekundärphotonen ist proportional der Energie der primären Gammas.
#
# Das Messsignal ist in der Regel eingebettet in einen kontinuierlichen Untergrund. Dieser entsteht durch Streifschüsse der $\gamma$ und hierdurch entstehende Compton-Photonen geringerer Energie.
#
# Typische zeitliche Auflösung: $10^{-7} s$ bis $10^{-10} s$.
# Energieauflösung für $^{137}\text{Cs}$ Gammas liegt bei $\approx 50 keV$
#
# ## $\gamma$-Strahlung, $\gamma$-Spektrometrie
# Als $\gamma$-Strahlung wird elektromagnetische Strahlung bezeichnet, die ihren Ursprung im Atomkern hat. Natürlich vorkommende $\gamma$-Strahlung trägt Energien zwischen $10^3$ und $10^6$ eV.
# Schick ist, dass durch die diskrete Natur der Zustände der Nuklide bei Übergängen jeweils charakteristische Gammas ausgesandt werden. Zusamlmen bilden sie das sogenannte $\gamma$-Linienspektrum welches wiederum zur identifikation einzelner Radionuklide genutzt werden kann. Beispielhaft wäre der Zerfall von $^{60}\text{Co}$ zu $^{60}\text{Ni}$.
# $$
# \begin{equation}
#     ^{60}\text{Co} \longrightarrow ^{60}\text{Ni}^{**} \longrightarrow ^{60}\text{Ni}^{*} + \gamma_{1,17 MeV} \longrightarrow ^{60}\text{Ni} + \gamma_{1,33 MeV}
# \end{equation}
# $$
#
# ## WW von $\gamma$-Strahlung mit Materie, Absorption
# ![alt text](referenzen/gamma_in_materie.jpg "Szintillationszähler")
# Quelle: Eichler, Kronfeldt, Sahm - "Das neue physikalische Grundpraktikum", 2016
#
# Beim Durchgang von $\gamma$-Quanten durch Materie gibt es im Wesentlichen drei Arten der Wechselwirkung die jeweils von der Energie der $\gamma$-Quanten abhängige Häufungswahrscheinlichkeiten besitzen. Diese drei Wechselwirkungsarten sind die Compton-Streuung, Paarbildung und der im Szintillationszähler ausgenutze (innere) **Fotoeffekt**. Hieraus folgt, dass es für eine sinnvolle Messung nötig ist die Wahrscheinlichkeit für ein Foto-Event und damit den auf sein Konto gehenden Anteil des Schwächungskoeffizienten zu maximieren.
# Im Bild zu sehen ist, dass für (reines?) $\text{NaJ}$ als Szintillationsmaterial oberhalb einer Energie von $\approx 1 MeV$ de facto keine fotoelektrische Wechselwirkung mehr stattfindet.
# Paarbildung wird erst bei relativ hohen Energien $\geq 10 MeV$ relevant, was bei den hier verwendeten $\gamma$-Strahlern praktisch zu vernachlässigen ist.
#
# Beim inneren Fotoeffekt werden $\gamma$-Quanten Elektronen im Valenzband absorbiert. Wenn die durch das $\gamma$-Quant eingebrachte Energie ausreicht um die Bandlücke zum Leitungsband zu überwinden, entsteht ein freies Elektron mit einer der eingebrachten Energie proportionalen kinetischen Energie. Auf dem Weg durch das Absorbermaterial hinterlässt es nun eine Spur ~der Verwüstung~ von Ionisationsprozessen entlang seiner Bahn.
# Ultimativ entstehen so also Strompulse deren Höhe der ursächlichen $\gamma$-Energie proportional eignen sich so zur Energie-/Nuklidbestimmung.
#
# ## Absorption in Materialien
# Lambert'sche Schwächungsgesetz
# $$
# \begin{gather}
#     P(d_{1/2}) = \frac{1}{2}P_0 = P_0 \cdot e^{-\mu d} \\
#     \Leftrightarrow \\
#     d = \frac{ln(2)}{\mu}
# \end{gather}
# $$
# mit der Strahlungsleistung $P$, der Schichtdicke $d$ und dem Schwächungskoeffizienten $\mu$. $\mu$ hängt wiederum von der Quantenenergie ab. Obige Gleichung gilt also nur in annäherungsweise bei kleinen Änderungen der $\gamma$-Energie.
#
# ## Radium 226, Folgeprodukte, Zerfallsreihe
# $$
# \begin{align}
#     ^{226}_{80}\text{Ra} &\longrightarrow ^{222}_{86}\text{Rn} + \alpha (+ \gamma_{186 keV}) \\
#     ^{222}_{86}\text{Rn} &\longrightarrow ^{218}_{84}\text{Po} + \alpha \\
#     ^{218}_{84}\text{Po} &\longrightarrow ^{214}_{82}\text{Pb} + \alpha \\
#     ^{214}_{82}\text{Pb} &\longrightarrow ^{214}_{83}\text{Bi} + \beta^- (+\gamma_{352, 295, 242, 53 keV} \\
#     ^{214}_{83}\text{Bi} &\longrightarrow ^{214}_{84}\text{Po} + \beta^- (+\gamma_{609 keV} \\
#     ...
# \end{align}
# $$
#
# ## Am-241, Co-60, Cs-137, Zerfall, $\gamma$-Quanten
# $^{137}Cs$ Fotopeak bei $662 \text{keV}$
# $^{60}Co$ Fotopeak bei $1173$ und $1333 \text{keV}$

# %% [markdown]
# # Durchführung - Abstract
# _____________________________________

# %% [markdown]
# In diesem Versuch wird das Messgerät **LB 2045** eingesetzt. Zunächst soll mit Hilfe des Eichstrahlers Cs137 eine Kalibriermessung durchgeführt werden.
# Anschließend sollen Energiespektren der Proben Am241, Cs137 und Co60 aufgenommen werden.
#
#            Sonde                             Probe
#         ┌────────────────┐                ┌─────────────────┐     Achse
#         │                │                │                 │  ┌───────
#         │                │                │                 │  │
#     ─ ─ ┼ ─ ─ ─ ─ ─ ─ ─ ─┼ ─ ─ ─ ─ ─ ─ ─ ─│─ ─ ─ ─ ─ ─ ─ ─ ─│─ ▼ ─
#         │                │    Distanz     │                 │
#         │                │◄──────────────►│                 │
#         └────────────────┘                └─────────────────┘
#
#
#
# Hierzu werden die Messsonde **NaJ-Sonde 80936** und Testpräparat auf einer optischen Bank so angeordnet, dass ihre Achsen kolinear angeordnet sind (siehe Skizze).

# %% [markdown]
# <img src="./footage/cs137_calib.jpg" alt="Drawing" style="width: 800px;"/>
# <img src="./footage/LB2045_specs.jpg" alt="Drawing" style="width: 500px;"/>
#
# Links: Messelektronik LB2045 nach Kalibrierung mit Cs137. Rechts: Auszug aus den [technischen Spezifikationen](https://www.berthold.com/?eID=dumpFile&t=f&download=1&logInUri=%2Fde%2Fmeinberthold%2F&f=14049&token=f1b34938c27542072ff425c7b2333eb66078eabd) der Messelektronik LB2045.

# %% [markdown]
# # Auswertung
# ____________________________________

# %% [markdown]
# ## Importe

# %% [markdown]
# >**Read the docs**
# >[https://lmfit.github.io/lmfit-py/](https://lmfit.github.io/lmfit-py/)
# >[https://www.scipy.org/docs.html](https://www.scipy.org/docs.html)

# %%
import os
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = "svg" # crisper plots
from scipy.signal import find_peaks
import scipy.interpolate as interp
import numpy as np
import pandas as pd
from lmfit import Model, Parameters
# uncomment below to install lmfit package
# ! pip install --user lmfit

# %%
sample_files = os.listdir("messdaten/txt/")
sample_files.sort()
print(sample_files)
# Out:
# ['Am241 2048 150s.TXT', 'Am241 256 150s.TXT', 'Ameritium.1min.TXT', 'Calib_Cs137.TXT', 'Casium.1min.TXT', 'Co60 2048 300s.TXT', 'Co60.TXT', 'Cs137 2048 150s.TXT', 'Cs137 256 150s.TXT', 'Kobalt.1min.TXT', 'Nulleffekt.TXT', 'Ra226 2048 150s.TXT', 'Ra226 256 150s.TXT', 'Radium.2min.hoch.TXT', 'Radium.2min.niedrig.TXT']

# %%
spl_lst = []
for i,file in enumerate(sample_files):
    with open(("messdaten/txt/" + file), newline='', encoding='utf-8') as path:
        frame = pd.read_csv(path, delimiter=';', skiprows=14)
        frame.columns = [col.strip() for col in frame] # stupid whitespaces t(-_-t)
        spl_lst.append(frame)
        del frame

# %% [markdown]
# ## Plots

# %%
# Nightowl mode
plt.style.use("default")
plt.style.use("dark_background")
cm = 1/2.54 # inch to cm, metric like brrr
size = 60

# %% [markdown]
# ### Gauss-Modelfunktion

# %% [markdown]
# $$
# \begin{equation}
# 	f(x) = \frac{a}{\sqrt{2\pi\sigma²}} \cdot exp\left(-\frac{(x-x_0)^2}{2\sigma^2}\right)
# \end{equation}
# $$
# mit $\frac{a}{\sqrt{2\pi\sigma²}} = A$
#
# $$
# \begin{equation}
# 	f(x) = A \cdot exp\left(-\frac{(x-x_0)^2}{2\sigma^2}\right)
# \end{equation}
# $$
#
# * $A :=$ Maximum
# * $x_0 :=$ Lage des Maximums
# * $\sigma² :=$ Standardabweichung
#
# Der horizontale Abstand der beiden x-Werte bei der Hälfte des Maximums wird *full width half maximum* (FWHM) genannt und gemeinhin zur Quantifizierung der Energieauflösung herangezogen. Er berechnet sich durch
# $$
# \begin{equation}
# FWHM = 2\sqrt{2ln(2)}\sigma
# \end{equation}
# $$

# %%
def gauss(x, A, center, sigma):
    return A * np.exp(-(x-center)**2/(2*sigma**2))

# %% [markdown]
# ### Kalibrierung an Cs137 und Nulleffekt

# %% [markdown]
# Nulleffektmessung über 5 Minuten von 0 bis 2048 keV.
#
# Mit Erhöhung der Auflösung verringert sich gleichzeitig die maximal abbildbare Energie. Da die Speicherbreite aber mit 1024 konstant bleibt entstehen "Lücken" im x-Array. Um diese Lücken zu füllen wird hier eine lineare Interpolation nach
# $$
# y(x) = y_1 + (x - x_1) \frac{y_2-y_1}{x_2-x_1}
# $$
# gewählt.
#
#            ┌─┬─┬─┬─┐   ┌─┬─┬─┬─┬─┬─┬─┬─┬─┬─
#            │x│x│x│x│ - │x│x│x│x│x│x│x│x│x│...
#            └┬┴┬┴┬┴┬┘   └─┴─┴─┴─┴─┴─┴─┴─┴─┴─
#             │ │ │ └─────────────────┐
#             │ │ │                   │
#             │ │ └───────────┐       │
#             │ │             │       │
#             │ └─────┐       │       │
#             │       │       │       │
#             │       │       │       │
#             ▼       ▼       ▼       ▼
#            ┌─┬─┬─┬─┬─┬─┬─┬─┬─┬─┬─┬─┬─┐
#            │x│ │ │ │x│ │ │ │x│ │ │ │x│
#            └─┴─┴─┴─┴─┴─┴─┴─┴─┴─┴─┴─┴─┘
#
# Zu erkennen ist ein deutlicher Peak im unteren Energiebereich und drei kleinere im oberen Mittel. Gemessen an der außerordentlich hohe Zählrate und der allgemeinen Form des Verlaufs wird darauf geschlossen, dass die Messung zur Korrektur der Zählraten der Präparate verworfen werden muss.

# %%
null2048 = spl_lst[10].iloc[:, 0].tolist()
# creation of reference arrays
null1024 = np.asarray(null2048[:511]) # cut null2048 in half giving an array of size 511
null256 = np.asarray(null2048[:127]) # cut null2048 by 1/8 giving an array of size 127
# interpolation back to full size of 1023
# 1024 keV
stretch = interp.interp1d(np.arange(null1024.size),null1024)
null1024 = stretch(np.linspace(0, null1024.size-1,1023))
# 256 keV
stretch = interp.interp1d(np.arange(null256.size),null256)
null256 = stretch(np.linspace(0, null256.size-1,1023))

fig, ax = plt.subplots(figsize=(30*cm, 30*(9/16)*cm))
ax.plot(np.linspace(0,1023,1023), null2048, lw=.5, label="Datenpunkte bei\nMessdauer 300,75s")
ax.set_xlabel("Kanäle")
ax.set_ylabel("Zählrate / ips")
ax.legend()
ax.set_title("Nulleffekt bei 0 - 2048 keV")

plt.tight_layout()

# %% [markdown]
# Funktion zur Energiekalibrierung nach dem [Bundesministerium für Umwelt, Naturschutz und nukleare Sicherheit](https://www.bmu.de/fileadmin/Daten_BMU/Download_PDF/Strahlenschutz/strlsch_messungen_gamma_grund_bf.pdf).
#
# $$
# E_j(K_j) = \sum_{i=0}e_i \cdot K_j^i
# $$
#
# Mit den Kalibrierkoeffizienten $e_i$ und den Soll-Energien $E_j$ an den Kanälen $K_j$. Für eine Kalibrierung an $n$ Peaks lassen sich die Kalibrierkoeffizienten $e_1$ bis $e_n$ finden durch lösen des linearen Gleichungssystems der Gestalt
#
# $$
# \begin{bmatrix}
# e_1K_1^1 & e_2K_1^2 & \dots & e_nK_1^n \\
# e_1K_2^1 & e_2K_2^2 & \dots & e_nK_2^n \\
# \dots & \dots & \dots & \dots \\
# e_nK_n^1 & e_2K_n^2 & \dots & e_nK_n^n \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# E_1 \\ E_2 \\ \dots \\ E_n
# \end{bmatrix}
# $$
# >Disclaimer: leider funktioniert untere Funktion nicht für Kalibrierungen auf mehr als drei Peaks. Warum ist zwar noch ungeklärt, eine Kalibrierung auf drei Punkte erscheint hier aber als ausreichend genau.

# %%
def channels_calib(channels, energies, u_arr, verbose=False):
	if len(channels) != len(energies):
		raise Exception("Ungleiche Anzahl Kanäle und Energien!")
	B = list(energies)
	A = [[channel**(j+1) for j in range(len(channels))] for channel in channels]
	coeffs = np.linalg.solve(A,B).astype('float64')
	if verbose == True:
		print("Koeffizientenmatrix: ",A,"\nOrdinatenmatrix: ",B)
		print("Kalibrierkoeffizienten: ",coeffs)

	def channel_calib(u_chan):
		C = 0
		for i, coeff in enumerate(coeffs):
			C += coeff * u_chan**(i+1)
		return C
	c_arr = [channel_calib(u_chan) for u_chan in u_arr]
	return c_arr, coeffs

# %% [markdown]
# Es wird ein Impulshöhenspektrum an Cs137 aufgenommen, zwei Normalverteilungen in die dominanten Peaks gefittet, die Lage ihrer Maxima Kanälen zugeordnet und in ``channels`` abgelegt.

# %%
yarr = np.asarray(spl_lst[3].iloc[:, 0])
xarr = np.linspace(0, 1023, len(yarr))

fig, ax = plt.subplots(figsize=(30*cm, 30*(9/16)*cm))
peaks, _ = find_peaks(yarr, height=100, prominence=(100, None), wlen=50)
xpeaks, ypeaks = [xarr[peak] for peak in peaks], [yarr[peak] for peak in peaks]
# ax.scatter(xpeaks, ypeaks, marker='x', color='r', s=10)
# ===============
gmodel = Model(gauss, prefix="l_") + Model(gauss, prefix="r_")
params = Parameters()
# add with tuples: (NAME VALUE VARY MIN  MAX  EXPR  BRUTE_STEP)
params.add_many(("l_A", ypeaks[0], True, 175),("l_center", xpeaks[0]), ("l_sigma", 1),("r_A", ypeaks[0]),("r_center", xpeaks[1]), ("r_sigma", 1))
result = gmodel.fit(yarr, params, x=xarr)
r_A, r_c, r_s, l_A, l_c, l_s = result.best_values.values()
# print(result.fit_report())
# ===============
channels = [l_c, r_c]
print("Kanäle ",channels)
ax.plot(xarr, yarr, lw=.5, label="Datenpunkte")
ax.plot(xarr, result.best_fit, lw=.5, label="Fit")
ax.axvline(l_c, 0, 1, ls=':', lw=1)
ax.axvline(r_c, 0, 1, ls=':', lw=1)
ax.set_xlim(0, max(xarr))
ax.set_title("Unkalibrierter Plot der Messung an Cs137, 0-1024 keV")
ax.set_xlabel("Energie / keV")
ax.set_ylabel("Zählrate / ips")
ax.legend()
plt.tight_layout()
# Out:
# Kanäle  [40.65973134327647, 660.5427710207953]

# %%
cs137_en256 = [32.19, 256]
cs137_en1024 = [32.19, 661.659, 1024]
cs137_en2048 = [32.19, 661.659, 2048]

if "channels256" not in globals():
	channels256 = [chan * 4 for chan in channels] + [1023]
	channels256.pop(-2)
if "channels1024" not in globals():
	channels1024 = channels + [1023]
if "channels2048" not in globals():
	channels2048 = [chan * 0.5 for chan in channels] + [1023]

# %% [markdown]
# Vergleich der *Verzerrungen* der Kanäle durch die Kalibrierung. Es ist zu sehen, dass die Energieauflösung nicht homogen über die Energiebereiche verteilt ist.

# %%
xarr = np.linspace(0, 1023, 1023)
xarr256, coeffs256 = channels_calib(channels256, cs137_en256, np.linspace(0, 1023, len(yarr)), verbose=True)
xarr1024, coeffs1024 = channels_calib(channels1024, cs137_en1024, np.linspace(0, 1023, len(yarr)), verbose=False)
xarr2048, coeffs2048 = channels_calib(channels2048, cs137_en2048, np.linspace(0, 1023, len(yarr)), verbose=False)
fig, ax = plt.subplots(1,3, figsize=(15,5))
for i, a in enumerate(ax):
	a.set_xlabel("Kanäle")
	a.set_ylabel("Energien / keV")
ax[0].plot(xarr, np.linspace(0, 256, len(xarr)), '--r', label="Unkalibriert")
ax[0].plot(xarr, xarr256, label="Kalibriert")
ax[1].plot(xarr, np.linspace(0, 1024, len(xarr)), '--r', label="Unkalibriert")
ax[1].plot(xarr, xarr1024, label="Kalibriert")
ax[2].plot(xarr, np.linspace(0, 2048, len(xarr)), '--r', label="Unkalibriert")
ax[2].plot(xarr, xarr2048, label="Kalibriert")

ax[0].set_title("256 keV")
ax[1].set_title("1024 keV")
ax[2].set_title("2048 keV")
for a in ax:
	a.legend()
fig.suptitle("Energieverlauf über Kanäle vor und nach Kalibrierung")
plt.tight_layout()
# Out:
# Koeffizientenmatrix:  [[162.63892537310588, 26451.420046518702], [1023, 1046529]]
# Ordinatenmatrix:  [32.19, 256]
# Kalibrierkoeffizienten:  [1.88032510e-01 6.08131662e-05]

# %%
yarr = np.asarray(spl_lst[3].iloc[:, 0])
fig, ax = plt.subplots(figsize=(30*cm, 30*(9/16)*cm))

peaks, _ = find_peaks(yarr, height=100, prominence=(100, None), wlen=50)
xpeaks, ypeaks = [xarr1024[peak] for peak in peaks], [yarr[peak] for peak in peaks]

ax.plot(xarr1024, yarr, lw=.5, label="Datenpunkte")

ax.annotate("Konversionslinie bei {} keV".format(round(xpeaks[0],1)), (xpeaks[0], ypeaks[0]), (xpeaks[0]+60, ypeaks[0]-20), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.1'})
ax.annotate("Rückstreupeak\n(mit zusammengekniffenen\nAugen erkennbar)", (190, 40), (190+60, 40+20), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.1'})
ax.annotate("$\\gamma$-Linie bei {} keV".format(round(xpeaks[1],1)), (xpeaks[1], ypeaks[1]), (xpeaks[1]+100, ypeaks[1]-50), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.2'})

ax.set_xlim(0, max(xarr1024))
ax.set_title("Cs137 nach Kalibrierung")
ax.set_xlabel("Energie / keV")
ax.set_ylabel("Zählrate / ips")
ax.legend()
plt.tight_layout()

# %% [markdown]
# ### Am241, Co60

# %%
yarr = spl_lst[1].iloc[:, 0]

fig, ax = plt.subplots(2,1,figsize=(30*cm, 30*(9/16)*cm), gridspec_kw={'height_ratios': [1, 2]})
# ===============
gmodel = Model(gauss, prefix="l_") + Model(gauss, prefix="c_") + Model(gauss, prefix="r_")
params = Parameters()
# add with tuples: (NAME VALUE VARY MIN  MAX  EXPR  BRUTE_STEP)
params.add_many(("l_A", 2500, True, 1500),("l_center", 10), ("l_sigma", 1),("c_A", 2500),("c_center", 20), ("c_sigma", 1),("r_A", 17500),("r_center", 40), ("r_sigma", 1))
result = gmodel.fit(yarr, params, x=xarr256)
r_A, r_c, r_s, c_A, c_c, c_s, l_A, l_c, l_s = result.best_values.values()
# print(result.fit_report())
# ===============
for i, axis in enumerate(ax):
	axis.plot(xarr256, yarr, lw=.5, label="Datenpunkte")
	axis.plot(xarr256, result.best_fit, ls='--', lw=.5, label="Fit")
	axis.set_xlim(0, max(xarr256)-i*(max(xarr256)-75))
	axis.set_xlabel("Energie / keV")
	axis.set_ylabel("Zählrate / ips")
	axis.legend()
ax[0].fill_between((0,75/max(xarr256)),0,1,transform=ax[0].transAxes, color='#000f00')
ax[1].annotate("$L$-Np237\nErwartet: 17 keV\nIst:{} keV".format(round(l_c, 1)), (l_c, l_A), (l_c-5, l_A+5000), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=-0.3'})
ax[1].annotate("$K_\\alpha$-Jod\nErwartet: 26,3 keV\nIst: {} keV".format(round(c_c, 1)), (c_c, 2500), (c_c+3, c_A+4500), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.3'})
ax[1].annotate("$\\gamma$-Np237\nErwartet: 59,54 keV\nIst: {} keV".format(round(r_c, 1)), (r_c, r_A), (r_c+5, r_A-3000), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.3'})
ax[1].text(0.01, 0.97, s="Die Lage der Peaks sind hier recht off.\nDas Delta scheint sich hin zu höheren\nEnergien zu intensivieren.", transform=ax[1].transAxes, verticalalignment='top')
fig.suptitle("Am214")

plt.tight_layout()

# %%
yarr = spl_lst[5].iloc[:, 0]

fig, ax = plt.subplots(2,1,figsize=(30*cm, 30*(9/16)*cm), gridspec_kw={'height_ratios': [1, 2]})
peaks, _ = find_peaks(yarr, height=100, prominence=(600, None), wlen=40)
xpeaks, ypeaks = [xarr2048[peak] for peak in peaks], [yarr[peak] for peak in peaks]
# ax[1].scatter(xpeaks, ypeaks, marker='x', color='r', s=10)
# ===============
for i, axis in enumerate(ax):
	axis.plot(xarr2048, yarr, lw=.5, label="Datenpunkte")
	axis.set_xlim(0, max(xarr2048)-i*(max(xarr2048)-1600))
	axis.set_xlabel("Energie / keV")
	axis.set_ylabel("Zählrate / ips")
	axis.legend()
ax[0].fill_between((0,1600/max(xarr2048)),0,1,transform=ax[0].transAxes, color='#000f00')
ax[1].annotate("Ist: {} keV".format(round(xpeaks[0], 1)), (xpeaks[0], ypeaks[0]), (xpeaks[0]+10, ypeaks[0]-3000), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=-0.1'})
ax[1].annotate("Ist: {} keV".format(round(xpeaks[1], 1)), (xpeaks[1], ypeaks[1]), (xpeaks[1]+3, ypeaks[1]+1000), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.1'})
ax[1].annotate("$\\gamma$-Ni60\nErwartet: 1173 keV\nIst: {} keV".format(round(xpeaks[2], 1)), (xpeaks[2], ypeaks[2]), (xpeaks[2]-200, ypeaks[2]-3000), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=-0.3'})
ax[1].annotate("$\\gamma$-Ni60\nErwartet: 1333 keV\nIst: {} keV".format(round(xpeaks[3], 1)), (xpeaks[3], ypeaks[3]), (xpeaks[3]+100, ypeaks[3]+500), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.3'})
ax[1].text(0.01, 0.97, s="Auch hier sind die Peaks relativ\nweit vom Erwartungswert entfernt.", transform=ax[1].transAxes, verticalalignment='top')
fig.suptitle("Co60")

plt.tight_layout()

# %% [markdown]
# ### Ra226

# %%
yarr = spl_lst[12].iloc[:, 0]
fig, ax = plt.subplots(figsize=(30*cm, 30*(9/16)*cm))
# ===============
ax.plot(xarr2048, yarr, lw=.5, label="Datenpunkte")
ax.set_xlim(0, max(xarr2048))
ax.set_xlabel("Energie / keV")
ax.set_ylabel("Zählrate / ips")
ax.legend()
ax.set_title("Ra226")
plt.tight_layout()

# %%
yarr = spl_lst[11].iloc[:, 0]
fig, ax = plt.subplots(2,1,figsize=(30*cm, 30*(9/16)*cm), gridspec_kw={'height_ratios': [1, 2]})
peaks, _ = find_peaks(yarr, height=100, prominence=(600, None), wlen=40)
xpeaks, ypeaks = [xarr2048[peak] for peak in peaks], [yarr[peak] for peak in peaks]
for i, axis in enumerate(ax):
	axis.plot(xarr2048, yarr, lw=.5, label="Datenpunkte")
	axis.set_xlim(0, max(xarr2048)-i*(max(xarr2048)-750))
	axis.set_xlabel("Energie / keV")
	axis.set_ylabel("Zählrate / ips")
	axis.legend()
ax[0].fill_between((0,750/max(xarr2048)),0,1,transform=ax[0].transAxes, color='#000f00')
ax[1].annotate("$K_{{\\alpha}}$\nIst: {} keV".format(round(xpeaks[0], 1)), (xpeaks[0], ypeaks[0]), (xpeaks[0]+60, ypeaks[0]-8000), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.2'})
ax[1].annotate("Rn222\nIst: {} keV".format(round(xpeaks[1], 1)), (xpeaks[1], ypeaks[1]), (xpeaks[1]-80, ypeaks[1]+5000), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.1'})
ax[1].annotate("Bi214\nIst: {} keV".format(round(xpeaks[2], 1)), (xpeaks[2], ypeaks[2]), (xpeaks[2]-100, ypeaks[2]+15000), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=-0.3'})
ax[1].annotate("Bi214\nIst: {} keV".format(round(xpeaks[3], 1)), (xpeaks[3], ypeaks[3]), (xpeaks[3]+20, ypeaks[3]+15000), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.1'})
ax[1].annotate("Bi214\nIst: {} keV".format(round(xpeaks[4], 1)), (xpeaks[4], ypeaks[4]), (xpeaks[4]+60, ypeaks[4]+1500), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.5'})
ax[1].annotate("Po214\nIst: {} keV".format(round(xpeaks[5], 1)), (xpeaks[5], ypeaks[5]), (xpeaks[5]+100, ypeaks[5]+500), fontsize=8, arrowprops={'arrowstyle': '->', 'connectionstyle': 'arc3,rad=0.3'})
fig.suptitle("Ra226")

plt.tight_layout()

# %% [markdown]
# Eingezeichnet sind nur die gemessenen Energien. Die zu erwartenden Energien für die Tochterkerne sind
# * Bi214: 53, 242, 295, 352 keV
# * Po214: 609 keV
# * Rn222: 186 keV
#
# Augenscheinlich weichen die eingezeichneten Energien deutlich von den zu Erwartenden ab. Es ist an diesem Punkt unklar, wo im Detail der Fehler liegt, die Vermutung liegt aber stark bei der Methode der Kalibrierung.
