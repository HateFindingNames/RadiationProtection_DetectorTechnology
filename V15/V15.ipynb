# %% [markdown]
# #  Vorbereitung - Reichweite, Absorption und Durchdringungsfähigkeit von $\alpha$-, $\beta$- und $\gamma$-Strahlung (Berthold LB 123 UMo mit LB 1236 und LB 1238)
# --------------------------------
# ## Gasionisationsdetektoren
# Das Funktionsprinzip von Gasionisationsdetektoren ist die Ausnutzung der ionisierenden Wechselwirkung zwischen der eintretenden, radioaktiven Strahlung und den Teilchen - bzw. genauer den Elektronenschalen - des Füllgases. Befinden sich die Ionen des Füllgases und die freien Elektronen in einem ausreichend starken äußeren elektrischen Feld, lassen sie sich zur Anode bzw. Kathode hin "sortieren" bevor sie dazu in der Lage sind zu rekombinieren, damit Ladungsneutral und letztlich unempfindlich gegenüber dem äußeren E-Feld zu werden.
# Ist das äußere E-Feld nun so stark um die Ladungen derart zu beschleunigen, dass sie ihrerseits durch Kollisionen Gasatomen ionisieren, wird der Gasionisationsdetektor als _Proportionalzähler_ betrieben. Die Bezeichnung rührt von dem Zusammenhang $E \propto N$ wobei $E$ das angelegte Feld und $N$ die Zählrate ist.
#
# ## Ionisationskammer, Proportionalzähler,
# S.o.
#
# ## $\alpha$, $\beta$, $\gamma$ - Strahlung
# $\alpha$-Strahlung bezeichnet ionisierende Strahlung, die meist ein Zerfallsprodukt instabiler Kerne ist und seinerseits ein $\frac{4}{2}He$-Kern darstellt.
#
# $\beta$-Strahlung entsteht ähnlich der $\alpha$-Strahlung bei Kernzerfällen. Hierbei wird jedoch ein Neutron in ein **Proton**, ein **Elektron** und ein **anti-Neutrino** umgewandelt. Auch möglich ist der Zerfall eines Protons unter Emission eines **Neutrons**, eines **Positrons** und eines **Neutrinos**. Es wird somit unterschieden in $\beta^-$-Zerfälle
# $
# \begin{equation}
#     n \longrightarrow p^+ + e^- + \bar{\nu}
# \end{equation}
# $
# und $\beta^+$-Zerfälle
# $
# \begin{equation}
#     p^+ \longrightarrow n + e^+ + \nu
# \end{equation}
# $
#
# $\gamma$-Strahlung zuletzt meint vom Nukleus eines Atoms emmitierte elektromagnetische Strahlung.
#
# ## WW von Strahlung mit Materie
# (!) Die Wechselwirkung (kurz WW) werden Strahlungen mit Energie von KeV und MeV von Mateire teilweise oder vollständig absorbiert. Die gamma-Strahlungen besitzen als EM-Wellen eine Photonenenergie von etwa 100 keV bis 5 MeV. Die Wahrscheinlichkeit, dass einer der folgende Wechselwirkungsmöglichkeiten auftreten, hängt von der Höhe der Energie.
#
# **Photoeffekt**: EM-Wellen wird von der inneren Elektronenschale übernommen und aus der Atomhülle gestoßen. Bei weiteren Wechselwirkungen kann es Bremsstrahlung auslösen oder andere Atome ionisieren. Durch den Defektelektron in der Atomhülle kann es zu Auger-Elektronen oder Fluoreszenzstrahlung führen.
#
# **Comptoneffekt**: Die EM-Wellen verlieren durch die WW mit ein Elektron an der Außenschale ein Teil deren Energie. Das Elektron wird weggestoßen und die Restenergie der EM-Welle gestreut.
#
# **Paarbildung**: Die WW findet an den Atomkern statt mit eine Photoenergie von ca. 1.022 MeV. Die EM-Welle schlägt aus den Atomkern ein Teilchen-Antiteilchenpaar und kann Bremmsstrahlungen oder Ionisationen erzeugen.
#
# Die alpha- und beta-Strahlungen sind geladene Teilchen. Die WW ist abhängig von der Masse, Ladung und Abstand des einlaufenden  Teilchens zum Wirkungszentrum.
#
# **Anregung**: Die geladene Teilchen geben bei der WW ein Teil der Energie ab und regen die Elektronen der inneren Schalen. Die Anregung des Elektrons zu eine äußere Schale hält kurzzeitig an und emittiert die überschüssige Energie wieder ab.
#
# **Ionisation**: Identisch zu der Anregung, besitzen die geladene Teilchen mehr Energie. Dies führt es zur Abstoßung von Elektronen an der inneren Schalen. Die Leerstelle ersetzt sich durch die Elektronen an der äußeren Schalen und dabei ein Teil deren Energie als EM-Welle.
#
# **Bremsstrahlung**: Entsteht durch die Richtungs- und Geschwindigkeitsänderung der Ladung. Das Teilchen wird durch den Kernfeld unter Energieverlust abgelenkt und ein Teil seiner Energie als EM-Welle aussenden.
#
# **Coulombstreuung**: Wenn die Teilchenenergie so hoch ist, dass das einlaufende Teilchen die Coloumbkräfte der Atomhülle durchsetzen, können sie direkt mit den Atomkernen wechselwirken. Dabei werden sie ohne Energieverlust gestreut.
#
# ## Nulleffekt (Nullrate)
#
# Eine von 0 verschiedene Zählrate trotz Abwesenheit eines aktiven Präparates und für gewöhnlich bedingt durch natürliche Strahlenquellen und/oder kosmische Hintergrundstrahlung.
#
# ## Strontium-90, Ameritium-241, Kobalt-60
# ### Ameritium-241
# Das Isotop $^{241}_{95}Am$ ist ein $\alpha$-Strahler nach
# $$
# \begin{equation}
#     ^{241}_{95}Am \longrightarrow ^{237}_{93}Np + \alpha + \gamma 59,54\text{keV}
# \end{equation}
# $$
# mit einer Halbwertszeit von $T_{1/2} = 432,2\text{a}$ und einer Zerfallsenergie von $\approx 5,486 \text{MeV}$. Mit einem atomaren Gewicht von $241,06\text{u}$ enthält $1\text{g}$ $^{241}_{95}Am$ schätzungsweise
# $
# \begin{equation}
#     1\text{u}^{-1} \cdot {1,661 \cdot 10^{-24}g \cdot 241,06u} \approx 2,5 \cdot 10^{21}
# \end{equation}
# $
# Kerne.
# Somit ist nach $A(t) = \frac{ln(2)}{T_{1/2}} \cdot N_0 \cdot e^{-\frac{ln(2)}{T_{1/2}}t}$ mit etwa $1,27 \cdot 10^{11}$ Zerfällen pro Sekunde zu rechnen.
#
# Das Zerfallsprodukt $^{237}Np$ besitzt eine Halbwertszeit von $2,144 \cdot 10^6\text{a}$(!) und wird damit mit irrelevant für die Messung angenommen.
#
# ### Strontium-90
# Das Isotop $^{90}_{38}Sr$ zerfällt durch $\beta^{-}$-Zerfall mit einer Halbwertszeit von $T_{1/2} = 28,8\text{a}$ und einer Zerfallsenergie von $\approx 0,546 \text{MeV}$. Das Zerfallsprodukt ist Ytterium-90.
# $
# \begin{equation}
#     ^{90}_{38}Sr \longrightarrow ^{90}_{39}Y + p^+ + e^- + \bar{\nu}
# \end{equation}
# $
# Mit einem atomaren Gewicht von $87,62\text{u}$ enthält $1\text{g}$ $^{90}_{38}Sr$
# $
# \begin{equation}
#     \frac{1u}{1,661 \cdot 10^{-24}g \cdot 87,62u} \approx 6,9 \cdot 10^{21}
# \end{equation}
# $
# Kerne.
# Somit sind nach $A(t) = \frac{ln(2)}{T_{1/2}} \cdot N_0 \cdot e^{-\frac{ln(2)}{T_{1/2}}t}$ mit etwa $5,24 \cdot 10^{12}$ Zerfällen pro Sekunde zu rechnen.
#
# $^{90}_{39}Y$ seinerseits zerfällt mit einer Halbwertszeit von $64.1\text{h}$ unter $\beta^-$-Emission relativ schnell weiter zu Zirconium-90 mit einer Zerfallsenergie von $2,28\text{MeV}$
# Die stöchiometrischen Faktoren ändern sich während der Zerfallsreihe nicht - wohl aber die Zerfallsenergie. Es ist also anzunehmen, dass während der Messung die durch den Zerfall des Spaltproduktes entstehende Strahlung in ihrer Energie dominieren wird. _Mit Blick auf die Zerfallsenergien der jeweiligen Strahler ist jedoch der maximale Messbereich des Kontaminationsmessgerätes zu beachten._
#
# ### Kobalt-60  (!)
# Das Isotop $^{60}_{27}Co$ zerfällt durch $\beta ^{-}$ -Strahlungen zu instabilen Ni-60 mit einer Zefallsenergie von 0,31 MeV. Davon entstehen weitere Emissionen mit den charakteristischen Fotopeaks von 1173 und 1333 keV als $\gamma$ -Strahlungen. Die Halbwertszeit des Isotopes liegt bei $T_{1/2}$ $\approx$ 5,27 a.
# $
# \begin{equation}
#     ^{60}_{27}Co \longrightarrow ^{60}_{28}Ni + e^- + \gamma 1173,1333\text{keV}
# \end{equation}
# $
#
# ## Aktivität, Dosisleistung
#
# ### (!) Aktivität
# (!) Die Aktivität einer radioaktiven Probe gibt den Erwartungswert der umgewandelten Teilchen über eine Zeit. Die Einheit der Aktivität lautet Becquerel $Bq$ und gibt die Anzahl der Umwandlungen pro Sekunde. Ein weiterer Part über die Aktivität ist die Zerfallskonstante $\lambda$. Die Zerfallskonstante ist materialspezifisch.
# \begin{equation}
#     A(t) = A_{0} \cdot e^{- \lambda \cdot t}
# \end{equation}
#
# ### (!) Dosisleistung
# (!) Beruht auf die Absorption von Strahlungsenergie mit Materie. Die Menge wird in Joule durch Kilogramm $J / kg$, auch als Gray $Gy$ genannt, angegeben. Die Absorption der Energie ist bei gleicher Strahlungsintensität  in jede Materie unterschiedlich. Deshalb muss bei der Energiedosisangabe immer das Absorbermaterial dazu gennant werden.
#
# # Absorptionsgesetz (Gültigkeit für $\alpha$ , $\beta$ , $\gamma$ -  Strahlung
# (!) Die Zählrate von einen Quellaparat ändert über die Dicke des Materials. Hinzu hängt es von der Schwächungskoeffizient $\mu$. Es setzt sich additiv aus den Koeffizienten für einzelnen Wechselwirkung  zusammen.
# \begin{equation}
#     I(d) = I_{0} \cdot e^{- \mu \cdot d}
# \end{equation}
# Die einzelne Komponente sind Energieabhängig und zeigt eine komplexe lineare Schwächungsverlauf mit der Photonenenergie. Er ist eine für das jeweilige Absorbermaterial wohl definierte und charakterische Größe.

# %% [markdown]
# # Durchführung - Abstract
# ---------------------------------------
#
# Messgerät **LB 123** zusammen mit den Messsonden **LB 1236** (beide bereits bekannt aus V7) und **LB 1238** werden zur Impulsratenmessung für $\alpha$/$\beta$ (Sonde **LB 1236**) und $\gamma$ (Sonde **LB 1238**) eingesetzt. Die Sonden werden hier so angeordnet, dass für $\alpha$,$\beta$-Messung die Achse der Sonde **parallel** zur Achse der Probe liegt. Für $\gamma$-Messung hingegen liegt die Achse der Sonde **senkrecht** zur Achse der Probe.
#
#              Sonde                             Probe
#           ┌────────────────┐                ┌─────────────────┐     Achse
#           │                │                │                 │  ┌───────
#           │                │                │                 │  │
#       ─ ─ ┼ ─ ─ ─ ─ ─ ─ ─ ─┼ ─ ─ ─ ─ ─ ─ ─ ─┼ ─ ─ ─ ─ ─ ─ ─ ─ ┼ ─▼─ ─
#           │                │                │                 │
#           │                │                │                 │
#           └────────────────┤                ├─────────────────┘
#                            │    Distanz     │
#                            │◄──────────────►│
#                            │                │
#
#
# >**Während des gesamten Versuchs muss darauf geachtet werden, dass Sonde und Probe nicht in Berührung kommen!**
#
# Warum? Durch Kontakt kann es zu Kontamination der Sonde selbst kommen. In Folge werden sämtliche Messunge neben dem Nulleffekt von einem zusätzlichen, der Kontamination entstammenden, Grundrauschen überlagert. (!) Die Distanz bei einer $\alpha$,$\beta$-Messung liegt bei 2 mm und bei $\gamma$-Messung bei 15 cm.
#
# ## Messonde LB 1238
# Aus den [technischen Spezifikationen](https://www.gammadata.se/products/radiation-detection/accessories-radiation-detection/lb-1238/) der Messonde LB 1238:
#
# >Counter tube: End-window proportional counter tube
# >Window: Ø 28 mm, 0.2 mg/cm²
# >Efficiency for point-shaped sources
# >     Sr-90 = 46%
# >     Am-241 = 18%
# >Temperature range:  -10 °C to +50 °C
# >Dimensions: 50 mm Ø x 275 mm
# >Weight: 0.46 kg
#
# ## Aufgabe 1
# (!) Die erste Aufgabe geht es um die Impulsrate der $\alpha$ von Am-241 und $\beta$ -Strahlung von Sr-90 über die Distanz zu bestimmen.

# %% [markdown]
# # Auswertung - Reichweiten $\alpha, \beta$
# -----------------------------------

# %% [markdown]
# **To-Do**
# * [ ] Bestimmen Sie die Impulsrate der **Am-241**-Quelle über einen sinnvollen Messbereich und plotten Sie diese. Ermitteln/Fitten Sie die Reichweite (der Ort, an dem 50% der ursprünglichen Impulsrate erreicht werden) und vergleichen Sie diese mit der aus der Literatur für Am-241 erwarteten Reichweite an Luft.
# * [ ] Bestimmen Sie die Impulsrate der **Sr-90**-Quelle über einen sinnvollen Messbereich und plotten Sie diese. Ermitteln/Fitten Sie die Reichweite (der Ort, an dem 50% der ursprünglichen Impulsrate erreicht werden) und vergleichen Sie diese mit der aus der Literatur für Sr-90 erwarteten Reichweite an Luft.

# %% [markdown]
# ## Importe

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = "svg" # crisper plots
import pandas as pd
from pandas import read_csv
import numpy as np
from scipy.optimize import curve_fit
from lmfit import Model, Parameters

# %%
# Nightowl mode
plt.style.use("default")
plt.style.use("dark_background")
cm = 1/2.54 # inch to cm, metric like brrr
size = 60

# %%
paths = [
    "./Messungen/Range/Am_A1.csv",
    "./Messungen/Range/Sr_A1.csv",
    "./Messungen/Absorption/Am_A2.csv",
    "./Messungen/Absorption/Co_A2.csv",
    "./Messungen/Absorption/Sr_A2.csv",]

with open(paths[0], newline='', encoding='utf-8-sig'):
    am1 = read_csv(paths[0], delimiter=';')
with open(paths[1], newline='', encoding='utf-8-sig'):
    sr1 = read_csv(paths[1], delimiter=';')
with open(paths[2], newline='', encoding='utf-8-sig'):
    am2 = read_csv(paths[2], delimiter=';')
with open(paths[3], newline='', encoding='utf-8-sig'):
    co2 = read_csv(paths[3], delimiter=';')
with open(paths[4], newline='', encoding='utf-8-sig'):
    sr2 = read_csv(paths[4], delimiter=';')

# %% [markdown]
# ## Modelfunktion

# %% [markdown]
# Der abgedeckte Raumwinkel der Messsonde LB1238 mit einem Öffnungsdurchmesser von D = 28 mm ergibt sich durch
# $$
# 	\omega = 2\pi \int_0^\alpha sin(\Theta) d\Theta = 2\pi\left( 1 - cos(\alpha) \right)
# $$
# was mit $\alpha = 2 \cdot arctan\left( \frac{D}{2r} \right)$ zu
# $$
# 	\omega(r) = 2\pi\left( 1 - cos\left(arctan\left( \frac{D}{2r} \right) \right) \right)
# $$
# und weiter vereinfacht zu
# $
# \begin{equation}
# 	\omega(r) = 4\pi sin\left(\frac{1}{2}arctan\left( \frac{D}{2r} \right) \right)^2
# \end{equation}
# $
# wird.
#
# Mit $\Omega = 4\pi$ lässt sich die Zählrate als Funktion des Abstandes schließlich beschreiben als
# $
# \begin{equation}
# 	I(r) = I_0 \cdot \frac{2 \cdot \omega(r)}{\Omega} = I_0 \cdot 2 sin\left(\frac{1}{2}arctan\left( \frac{D}{2r} \right) \right)^2
# \end{equation}
# $
#
# * $\Omega$: Voller Raumwinkel
# * $\omega$: Abgedeckter Raumwinkel
# * $r$: Abstand Quelle-Detektorfenster
# * $D$: Durchmesser des Detektorfensters

# %%
def dist_law(r, I0=1):
	return I0 * (1**2 / r**2)

def solid_angle_cone(x, I0=1, D=28):
	return I0 * 2 * np.sin(0.5*np.arctan(0.5*D/x))**2

def expo_decay(x, I0=1, lambd=1):
	return I0 * np.exp(-lambd*x)

solid_angle_cone(10, 1, 28)
# Out:
# 0.41876180628090354

# %% [markdown]
# ## Bestimmung der Reichweiten

# %% [markdown]
# ### Am241 ($\alpha$)

# %%
xarr = am1["cm"]
yarr = am1["ips"]
yerr = am1["Err ips"]

line = lambda x, m, b: m*x+b
popt, _ = curve_fit(line, xarr, yarr)

fig, ax = plt.subplots(figsize=(30*cm, 30*(9/16)*cm))

ax.scatter(xarr, yarr, s=10)
ax.plot(xarr, line(xarr, *popt), label="Fit")
ax.axhline(0.5*max(yarr), xmin=0, xmax=1, linestyle=':', alpha=.5)
ax.axvline(4.104, ymin=0, ymax=1, linestyle=':', alpha=.5, color='#00ff00', label="$\\frac{1}{2}I_0$ (4.104 cm, NIST)")
ax.axvline(-0.5*popt[1]/popt[0], ymin=0, ymax=1, ls=':', alpha=.5, color='#ff0000', label="$\\frac{{1}}{{2}}I_0$ ({} cm, empirisch)".format(round(-0.5*popt[1]/popt[0], 3)))
# ax.vlines()
ax.set_xlabel("Abstand / cm")
ax.set_ylabel("Zählrate / ips")
ax.set_title("Reichweite $\\alpha$ 5486 keV (Am241) in Luft")
ax.legend()
plt.tight_layout()

# %%
with open('./referenzen/NIST/alpha_csda_air.csv', newline='', encoding='utf-8-sig') as file:
    alpha_csda = read_csv(file, delimiter=';', skiprows=5)

density_air = 0.001255 # g/cm3
xarr = alpha_csda["Energy"]
yarr = alpha_csda["Range"] / density_air

fig, ax = plt.subplots()
ax.plot(xarr, yarr)
ax.scatter(5.486, 4.104)
ax.vlines(5.486, ymin=0, ymax=4.104, ls=':', alpha=.5)
ax.hlines(4.104, xmin=0, xmax=5.486, ls=':', alpha=.5)
ax.annotate("Am241", (5.486, 4.104), (6.9, 3.2), verticalalignment='top')
ax.set_title("$\\alpha$ mittlere Reichweite in Luft")
ax.set_xlabel("Energie / MeV")
ax.set_ylabel("Reichweite / cm")
ax.set_xscale('log')
ax.set_yscale('log')
plt.tight_layout()

# %% [markdown]
# ### Sr90 ($\beta^-$)

# %%
xarr = sr1["cm"]
yarr = sr1["ips"]
yerr = sr1["Err ips"]
x = np.arange(0,max(xarr)+1, 1)

fig, ax = plt.subplots(figsize=(30*cm, 30*(9/16)*cm))
# ========= Solid Angle Fit ==============
smodel = Model(solid_angle_cone)
params = Parameters()
params.add("I0", value=max(yarr), min=5000)
params.add("D", value=28, vary=True)
result = smodel.fit(yarr, params, x=xarr)
# print(result.fit_report())
anvals = list(result.best_values.values())
ax.plot(x, solid_angle_cone(x, *anvals), label="$\\frac{2\omega}{\Omega}$ Fit")
# ========== Expo decay fit ==============
emodel = Model(expo_decay)
pars = Parameters()
pars.add("I0", value=max(yarr), vary=True)
pars.add("lambd", value=0.1)
result = emodel.fit(yarr, pars, x=xarr)
# print(fit_report(result))
exvals = list(result.best_values.values())
ax.plot(x, expo_decay(x, *exvals), label="Expo fit")
# ========================================
ax.scatter(xarr, yarr, s=10)

dh = np.log(2)/exvals[1]
hm = 0.5*max(yarr)
ax.hlines(hm, xmin=0, xmax=dh, linestyle=':', alpha=.5)
ax.vlines(dh, ymin=0, ymax=hm, ls=':', alpha=.5)
ax.annotate("Halbwertreichweite {}".format(round(dh,2)), (dh, hm), (dh+3, hm+1000), arrowprops={'arrowstyle': '->'})
ax.set_xlabel("Abstand / cm")
ax.set_ylabel("Zählrate / ips")
ax.set_title("Reichweite $\\beta^-$ in Luft (Sr90)")
ax.legend()
plt.tight_layout()
# Out:
# /tmp/ipykernel_13393/2594805036.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   return I0 * 2 * np.sin(0.5*np.arctan(0.5*D/x))**2

# %%
with open('./referenzen/NIST/beta_csda_air.csv', newline='', encoding='utf-8-sig') as file:
    beta_csda = read_csv(file, delimiter=';', skiprows=5)

density_air = 0.001255 # g/cm3
xarr = beta_csda["Energy"]
yarr = beta_csda["Range"] / density_air

fig, ax = plt.subplots()
ax.plot(xarr, yarr)
ax.scatter(0.546, 185.63)
ax.vlines(0.546, ymin=0, ymax=185.63, ls=':', alpha=.5)
ax.hlines(183.63, xmin=0, xmax=0.546, ls=':', alpha=.5)
ax.annotate("Sr90", (0.546, 185.63), (0.7, 160), verticalalignment='top')
ax.set_title("$\\beta^-$ Halbwertreichweiten in Luft")
ax.set_xlabel("Energie / MeV")
ax.set_ylabel("Reichweite / cm")
ax.set_xscale('log')
ax.set_yscale('log')
plt.tight_layout()

# %% [markdown]
# ## Bestimmung der Absorption in Materialien

# %% [markdown]
# ### Am241 ($\alpha$)

# %% [markdown]
# Um die Absorption von $\alpha$-Strahlung in Materie zu untersuchen, lagen zwei Am241-Präparate mit verschieden hoher Aktivität zur Verfügung. In beiden Fällen genügt eine Schicht ordinären Büropapieres, um die Zählrate auf das Niveau der Nullrate zu bringen.

# %%
am2
# Out:
#    Messung  Am (Probe1)  Am (Probe2)  Am (Probe1) Papier(1)  Nullrate
# 0        1         23.0         0.06                      0         0
# 1        2         22.9         0.04                      0         0
# 2        3         22.5         0.04                      0         0
# 3        4         22.6         0.04                      0         0
# 4        5         22.8         0.04                      0         0
# 5        6         23.0         0.04                      0         0
# 6        7         22.9         0.04                      0         0
# 7        8         22.9         0.04                      0         0
# 8        9         22.8         0.04                      0         0
# 9       10         22.8         0.04                      0         0

# %% [markdown]
# ### Sr90 ($\beta^-$)

# %%
sr2
# Out:
#    Messung  Papier(0)  Papier(4)  Papier(16)  Papier(64)  4.95mm Fe  Nullrate
# 0        1       2673       2317        1632         193        1.2      0.32
# 1        2       2672       2317        1635         194        1.2      0.31
# 2        3       2671       2316        1630         194        1.2      0.33
# 3        4       2671       2314        1629         194        1.2      0.30
# 4        5       2671       2316        1632         195        1.2      0.29
# 5        6       2671       2315        1635         195        1.2      0.29
# 6        7       2671       2313        1634         195        1.2      0.30
# 7        8       2671       2314        1633         195        1.2      0.29
# 8        9       2670       2315        1632         196        1.2      0.29
# 9       10       2671       2314        1631         197        1.2      0.28

# %%
p0, p4, p16, p64 = sr2["Papier(0)"].mean(), sr2["Papier(4)"].mean(), sr2["Papier(16)"].mean(), sr2["Papier(64)"].mean()
fe = sr2["4.95mm Fe"].mean()
null = sr2["Nullrate"].mean()
print("Zählrate nach 4.95mm Eisen: {}".format(fe-null))

xarr = [0,4,16,64]
yarr = [p0, p4, p16, p64] - null
x = np.arange(0,65,1)

fig, ax = plt.subplots(figsize=(30*cm, 30*(9/16)*cm))
# ==================================
emodel = Model(expo_decay)
pars = Parameters()
pars.add("I0", value=p0)
pars.add("lambd", value=2, min=0.001)
result = emodel.fit(yarr, pars, x=xarr)
# print(result.fit_report())
I0, lambd = list(result.best_values.values())
plt.plot(x, expo_decay(x, I0, lambd), label="Expo fit")
# ==================================
plt.scatter(xarr, yarr, label="Messpunkte")
# Annotation stuff
dh = np.log(2)/lambd
hm = (p0-null)/2
plt.hlines(hm, xmin=0, xmax=dh, ls=':', alpha=.5)
plt.vlines(dh, ymin=0, ymax=hm, ls=':', alpha=.5)
plt.annotate("$d_{{\\frac{{1}}{{2}}}}$ = {}".format(int(dh)), (dh, hm), (dh+3, hm+200), arrowprops={'arrowstyle': '->'})

plt.title("$\\beta^-$ durch Papier (Sr90)")
plt.xlabel("Schichten Papier")
plt.ylabel("Zählrate / ips")
plt.legend()
plt.tight_layout()
# Out:
# Zählrate nach 4.95mm Eisen: 0.8999999999999997

# %%
with open('./referenzen/NIST/beta_csda_fe.csv', newline='', encoding='utf-8-sig') as file:
    beta_csda = read_csv(file, delimiter=';', skiprows=5)

density_fe = 7.874 # g/cm3
xarr = beta_csda["Energy"]
yarr = beta_csda["Range"] / density_fe
dh = 0.037
en = 0.546

fig, ax = plt.subplots()
ax.plot(xarr, yarr)
ax.scatter(en, dh)
ax.vlines(en, ymin=0, ymax=dh, ls=':', alpha=.5)
ax.hlines(dh, xmin=0, xmax=en, ls=':', alpha=.5)
ax.annotate("Sr90", (en, dh), (en+0.2, dh), verticalalignment='top')
ax.set_title("$\\beta^-$ Halbwertreichweiten in Eisen")
ax.set_xlabel("Energie / MeV")
ax.set_ylabel("Reichweite / cm")
ax.set_xscale('log')
ax.set_yscale('log')
plt.tight_layout()

# %% [markdown]
# ### Co60 ($\gamma$)

# %%
co2
# Out:
#    Messung  0mm Fe  9.85mm Fe  40mm Fe  50mm Pb  100mm Pb  Nullrate
# 0        1   7.709      6.445    3.166    1.189     0.604     0.409
# 1        2   7.906      6.431    3.192    1.165     0.615     0.442
# 2        3   7.716      6.456    3.175    1.170     0.623     0.452
# 3        4   7.696      6.506    3.177    1.167     0.630     0.460
# 4        5   7.694      6.492    3.270    1.155     0.636     0.485
# 5        6   7.676      6.506    3.276    1.135     0.655     0.495
# 6        7   7.710      6.492    3.314    1.107     0.646     0.524
# 7        8   7.615      6.506    3.296    1.097     0.635     0.519
# 8        9   7.637      6.446    3.305    1.087     0.642     0.523
# 9       10   7.759      6.428    3.311    1.070     0.637     0.536

# %%
fe0, fe10, fe40 = co2["0mm Fe"].mean(), co2["9.85mm Fe"].mean(), co2["40mm Fe"].mean()
pb50, pb100 = co2["50mm Pb"].mean(), co2["100mm Pb"].mean()
null = co2["Nullrate"].mean()
fexarr = [0,9.85,40]
feyarr = [fe0,fe10,fe40] - null
pbxarr = [0,50,100]
pbyarr = [fe0, pb50, pb100] - null
x = np.arange(0,101,1)

fig, ax = plt.subplots(figsize=(30*cm, 30*(9/16)*cm))
# ==================================
emodel = Model(expo_decay)
pars = Parameters()
pars.add("I0", value=fe0)
pars.add("lambd", value=0.02, min=0.001)
feresult = emodel.fit(feyarr, pars, x=fexarr)
pbresult = emodel.fit(pbyarr, pars, x=pbxarr)
# print(result.fit_report())
I0, lambd_fe = list(feresult.best_values.values())
_, lambd_pb = list(pbresult.best_values.values())
plt.plot(x, expo_decay(x, I0, lambd_fe), label="Eisen fit")
plt.plot(x, expo_decay(x, I0, lambd_pb), label="Blei fit")
# ==================================
plt.scatter(fexarr, feyarr, label="Eisen")
plt.scatter(pbxarr, pbyarr, label="Blei")
# Annotation stuff
hm = (fe0-null)/2
dh_fe = np.log(2)/lambd_fe
dh_pb = np.log(2)/lambd_pb
plt.hlines((fe0-null)/2, xmin=0, xmax=dh_fe, ls=':', alpha=.5)
plt.vlines(dh_fe, ymin=0, ymax=hm, ls=':', alpha=.5)
plt.vlines(dh_pb, ymin=0, ymax=hm, ls=':', alpha=.5)
plt.annotate("$d_{{\\frac{{1}}{{2}},Fe}}$ = {}mm".format(round(dh_fe,2)), (dh_fe, hm), (dh_fe+5, hm+1), arrowprops={'arrowstyle': '->'})
plt.annotate("$d_{{\\frac{{1}}{{2}},Pb}}$ = {}mm".format(round(dh_pb,2)), (dh_pb, hm), (dh_pb+5, hm+2), arrowprops={'arrowstyle': '->'})

plt.title("$\\gamma$ durch Eisen und Blei (Co60)")
plt.xlabel("Materialdicken / mm")
plt.ylabel("Zählraten / ips")
plt.xlim(right=100)
plt.legend()
plt.tight_layout()
