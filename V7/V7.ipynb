# %% [markdown]
# # Vorbereitung

# %% [markdown]
# --> Read The Docs <--
# [https://www.scipy.org/](https://www.scipy.org/)

# %% [markdown]
# ## Gasionisationsdetektoren, Proportionalzähler
# Das Funktionsprinzip von Gasionisationsdetektoren ist die Ausnutzung der ionisierenden Wechselwirkung zwischen der eintretenden, radioaktiven Strahlung und den Teilchen - bzw. genauer den Elektronenschalen - des Füllgases. Befinden sich die Ionen des Füllgases und die freien Elektronen in einem ausreichend starken äußeren elektrischen Feld, lassen sie sich zur Anode bzw. Kathode hin "sortieren" bevor sie dazu in der Lage sind zu rekombinieren, damit Ladungsneutral und letztlich unempfindlich gegenüber dem äußeren E-Feld zu werden.
# Ist das äußere E-Feld nun so stark um die Ladungen derart zu beschleunigen, dass sie ihrerseits durch Kollisionen Gasatomen ionisieren, wird der Gasionisationsdetektor als _Proportionalzähler_ betrieben. Die Bezeichnung rührt von dem Zusammenhang $E \propto N$ wobei $E$ das angelegte Feld und $N$ die Zählrate ist.

# %% [markdown]
# ## $\alpha$, $\beta$, $\gamma$-Strahlung
# $\alpha$-Strahlung bezeichnet ionisierende Strahlung, die meist ein Zerfallsprodukt instabiler Kerne ist und seinerseits ein $\frac{4}{2}He$-Kern darstellt.
#
# $\beta$-Strahlung entsteht ähnlich der $\alpha$-Strahlung bei Kernzerfällen. Hierbei wird jedoch ein Neutron in ein **Proton**, ein **Elektron** und ein **anti-Neutrino** umgewandelt. Auch möglich ist der Zerfall eines Protons unter Emission eines **Neutrons**, eines **Positrons** und eines **Neutrinos**. Es wird somit unterschieden in $\beta^-$-Zerfälle
# $$ n \longrightarrow p^+ + e^- + \bar{\nu} $$
# und $\beta^+$-Zerfälle
# $$
#     p^+ \longrightarrow n + e^+ + \nu
# $$
#
# $\gamma$-Strahlung zuletzt meint vom Nukleus eines Atoms emmitierte elektromagnetische Strahlung.

# %% [markdown]
# ## Oberflächenkontamination
# _"Durch radioaktive Stoffe verursachte Verunreinigung auf der Oberfläche eines Materials."_ - Quelle: Bundesamt für Strahlenschutz.

# %% [markdown]
# ## Kontaminationsmonitor _Minicont H 1370 W_

# %% [markdown]
# Fläche: 160 cm²
#
# Messbereich: 0,1 bis 10 000 Imp/s
#
# <div>
# <img src="./referenzen/minicon.png" width="300"/>
# </div>
#
# Quelle: [http://ff-neckarau.de/technik/geraete/messgeraete](http://ff-neckarau.de/technik/geraete/messgeraete)

# %% [markdown]
# ## _Berthold LB123 UMo_ mit _LB 1236 Messsonde_
#
# Es konnten leider keine näheren Informationen zu exakt diesem Gerät gefunden werden. Mit der Unterstellung jedoch, dass es sich bei dem Gerät mit der Bezeichnung LB 134 Umo II um einen ähnlichen Typ handelt, haben wir es hier - in Kombination mit der Gamma-Sonde LB 1236-H10 - mit einem Dosisleistungsmonitor für Gamma- und Röntgenstrahlung mit _"tragbarer Auswerteeinheit"_ zu tun.
#
# Messbereich: $50 \frac{nSv}{h}$ bis $10 \frac{mSv}{h}$
# Energiebereich: $30 \text{keV}$ bis $1,3 \text{MeV}$
#
# <div>
# <img src="./referenzen/LB134_und_LB1236-H10.jpg" width="300"/>
# </div>
#
# Quelle: https://www.berthold.com

# %% [markdown]
# ## Impulsraten, Nulleffekt (Nullrate)
# Auch bei Abwesenheit und nach gewissenhaftem Reinigen der Messapparatur wird es eine von null verschiedene Zählrate $N_0$ geben - sie wird _Nullrate_ genannt.

# %% [markdown]
# ## Ameritium-241, Zerfallsart, Strahlenart
# Das Isotop $^{241}_{95}Am$ ist ein $\alpha$-Strahler nach
# $$
#     ^{241}_{95}Am \quad \longrightarrow \quad ^{237}_{93}Np + \alpha + \gamma 59,54\text{keV}
# $$
# mit einer Halbwertszeit von $T_{1/2} = 432,2\text{a}$ und einer Zerfallsenergie von $\approx 5,486 \text{MeV}$. Mit einem atomaren Gewicht von $241,06\text{u}$ enthält $1\text{g}$ $^{241}_{95}Am$ schätzungsweise
# $$
#     1\text{u}^{-1} \cdot {1,661 \cdot 10^{-24}g \cdot 241,06u} \approx 2,5 \cdot 10^{21}
# $$
# Kerne.
# Somit ist nach $A(t) = \frac{ln(2)}{T_{1/2}} \cdot N_0 \cdot e^{-\frac{ln(2)}{T_{1/2}}t}$ mit etwa $1,27 \cdot 10^{11}$ Zerfällen pro Sekunde zu rechnen.
#
# Das Zerfallsprodukt $^{237}Np$ besitzt eine Halbwertszeit von $2,144 \cdot 10^6\text{a}$ (!) und wird so als irrelevant für die Messung angenommen.

# %% [markdown]
# ## Strontium 90, Zerfallsart, Strahlenart
#
# Das Isotop $^{90}_{38}Sr$ zerfällt durch $\beta^{-}$-Zerfall mit einer Halbwertszeit von $T_{1/2} = 28,8\text{a}$ und einer Zerfallsenergie von $\approx 0,546 \text{MeV}$. Das Zerfallsprodukt ist $^{90}_{39}Y$.
# $$
#     ^{90}_{38}Sr \quad \longrightarrow \quad ^{90}_{39}Y + p^+ + e^- + \bar{\nu}
# $$
# Mit einem atomaren Gewicht von $87,62\text{u}$ enthält 1 g $^{90}_{38}Sr$
# $$
#     \frac{1u}{1,661 \cdot 10^{-24}g \cdot 87,62u} \approx 6,9 \cdot 10^{21}
# $$
# Kerne.
#
# Somit ist nach
# $$A(t) = \frac{ln(2)}{T_{1/2}} \cdot N_0 \cdot e^{-\frac{ln(2)}{T_{1/2}}t}$$
# mit etwa $5,24 \cdot 10^{12}$ Zerfällen pro Sekunde zu rechnen.
#
# $^{90}_{39}Y$ seinerseits zerfällt mit einer Halbwertszeit von $64.1\text{h}$ unter $\beta^-$-Emission relativ schnell weiter zu $^{90}_{40}Zr$ mit einer Zerfallsenergie von $2,28\text{MeV}$
# Die stöchiometrischen Faktoren ändern sich während der Zerfallsreihe nicht - wohl aber die Zerfallsenergie. Es ist also anzunehmen, dass während der Messung die durch den Zerfall des Spaltproduktes entstehende Strahlung in ihrer Energie dominieren wird. _Mit Blick auf die Zerfallsenergien der jeweiligen Strahler ist jedoch der maximale Messbereich des Kontaminationsmessgerätes zu beachten._

# %% [markdown]
# ## Abstandsgesetz, Geometriefaktor
# Das Abstandsgesetz besagt, dass die Intensität $I$ mit dem Quadrat zur Entfernung der Quelle abnimmt. Oder in anderen Worten: $I(r) \propto \frac{1}{r^2}$
#
# Der Geometriefaktor hängt damit eng zusammen: er ist eine Einheitenlose Zahl und gibt das Verhältnis des vom Detektor eingeschlossenen Raumwinkels um die Probe zum Gesamtraumwinkel an. Bei einem Geometriefaktor von 1 umschließt das Zählvolumen des Messgerätes den gesamten Raumwinkel um die Probe - sämtliche emittierte Strahlung muss das Zählvolumen passieren. Im Falle der Messung von Oberflächenkontamination ist demnach der Geometriefaktor mit $0,5$ (theoretisch) maximiert bei Aufliegen des Messgerätes auf der zu messenden Oberfläche.

# %% [markdown]
# ### Gerätekontrolle
#
# Vor der Messung wurde das Messgerät gemäß beigelegtem Handbuch auf Funktion überprüft. Hierin beinhaltet war
# * Eine Kontrolle des Ladezustandes der Batterie mittels Test-Taster und Ablesen an der Analoganzeige
# * Kontrolle der Folie am Boden des Gerätes auf Beschädigung
# * Überprüfen des Füllstandes des Zählgases (hier ein Blend aus 85 % Vol. Butan und 15 % Vol. Propan) am hierfür vorgesehenen Sichtfenster
# * Spülen der Zählkammer mit dem Zählgas um Kontamination (und damit False-Positives der Zählrate) durch z.B. Umgebungsluft zu verringern.

# %% [markdown]
# ### Anzeigegenauigkeit prüfen
#
# Im Aufbewahrungskoffer des Messgerätes befinden sich zwei Eichstrahler $^{241}Am$ und $^{90}Sr$. Um die Messgenauigkeit des Gerätes zu überprüfen wird an ihnen jeweils eine kontinuierliche Messung durchgeführt, während derer in Intervallen von etwa fünf Sekunden 10 Momentanwerte abgelesen und aufgezeichnet werden. Vergleich des arithmetischen Mittels der beiden Messreihen
# mit der erwarteten Aktivität der Präparate gibt schließlich Aufschluss über die Messgenauigkeit des Messgerätes.
# Für die erwartete Aktivität ist das Alter der Präparate zu beachten: Auf den Präparaten selbst ist eine gemessene Zählrate das Jahr der Messung Dokumentiert. Für Vielfache von fünf Jahren nach der dokumentierten Messung sind dem Handbuch Korrekturfaktoren zu entnehmen, die der Zählrate aufmultipliziert werden müssen.
#
# Im vorliegenden Fall jedoch übersteigt das Alter der Eichpräparate die im Handbuch gelisteten Korrekturfaktoren für die zu erwartenden Zählraten (siehe Abbildung). Aus Mangel der spontanen Verfügbarkeit jüngerer, bekannter Proben wurden die Korrekturfaktoren auf das Datum des Versuches extrapoliert.
#
# <div>
# <img src="./referenzen/korrekturfaktoren.jpg" width="300"/>
# </div>

# %% [markdown]
# ### Erwartungswerte
# #### Strontium-90
# Im Jahr 1987 wurde der mitgelieferte Prüfstrahler $^{90}Sr$ mit einer Impulsrate von 450 ips gemessen. Mit einer Halbwertszeit des Prüfstrahlers von $T_{1/2} = 28,8$ a ist zum Zeitpunkt der Messung (2021) mit einem Korrekturfaktor von
# $$
# k_{Am} = e^{\frac{\ln 2}{28,8a} \cdot 34a} \approx 0,441
# $$
# zu rechnen.
#
# Die zu erwartende momentante Aktivität errechnet sich so zu $\approx 198,45$ ips.
#
# #### Americium-241
# Analog errechnet sich der Korrekturfaktor für den Prüfstrahler $^{241}Am$ mit einer Halbwertszeit von $432,2$ a zu $\approx 0,947$. Ebenfalls für das Jahr 1987 wurde eine Aktivität von 200 ips angegeben. Die zu erwartende Aktivität zum Zeitpunkt der Messung ergibt sich so zu $\approx 189,4$ ips.

# %% [markdown]
# ### Referenzmessungen
#  Zunächst erfolgen eine Reihe von Messungen für $^{241}Am$, $^{90}Sr$ und die Nullrate jeweils bei der Drehschalterstellung **a** und **a+b**. Eine Minute nach dem Ein/Umschalten werden bei direktem Auflegen des Messgerätes auf die jeweilige Probe 10 Messwerte in Intervallen von fünf Sekunden aufgezeichnet. Da der Zeiger hier jedoch nicht bei einem Messwert zum liegen kommt wird der mittlere Wert gewählt, um den der Zeiger schwingt. Zur Ermittlung der Nullrate wird das Messgerät mindestens einen Meter entfernt von umliegenden Strahlenquellen auf den Labortisch gelegt.
#
#  Untenstehend sind die ermittelnden Messwerte tabellarisch aufgeführt.

# %%
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit

# %%
# Paths containing the data
paths = ["./messdaten/proben.csv",
        "./messdaten/referenz.csv",
        "./messdaten/proben_seitlich.csv"]

# Opening the data files one at a time
with open(paths[0], newline='' , encoding='utf-8-sig'):
    unkn1 = pd.read_csv(paths[0], delimiter=';')
with open(paths[1], newline='' , encoding='utf-8-sig'):
    ref = pd.read_csv(paths[1], delimiter=';')
with open(paths[2], newline='' , encoding='utf-8-sig'):
    unkn2 = pd.read_csv(paths[2], delimiter=';')

# %%
print('Tab 1: Impulsraten der Referenzmessungen mit den Eichstrahlern, sowie der Nullrate.')
ref
# Out:
# Tab 1: Impulsraten der Referenzmessungen mit den Eichstrahlern, sowie der Nullrate.
#    Sample  Nullrate a [ips]  Nullrate a+b [ips]  Sr a [ips]  Sr a+b [ips]  \
# 0       1               0.2                   5         0.4           200
# 1       2               0.2                   4         0.4           200
# 2       3               0.2                   7         0.3           200
# 3       4               0.2                   6         0.3           100
# 4       5               0.2                   5         0.4           200
# 5       6               0.2                   5         0.4           200
# 6       7               0.2                   4         0.4           200
# 7       8               0.2                   4         0.4           200
# 8       9               0.1                   6         0.3           200
# 9      10               0.2                   9         0.3           200
#
#    Am a [ips]  Am a+b [ips]
# 0         200            60
# ...

# %% [markdown]
# Des Weiteren werden jeweils arithmetische Mittel und Standardabweichungen ermittelt.

# %%
means = ref.iloc[0:, 1:].mean(axis=0)
print('Mittelwerte')
means
# Out:
# Mittelwerte
# Nullrate a [ips]        0.19
# Nullrate a+b [ips]      5.50
# Sr a [ips]              0.36
# Sr a+b [ips]          190.00
# Am a [ips]            230.00
# Am a+b [ips]           57.00
# dtype: float64

# %%
std = ref.iloc[0:, 1:].std(axis=0, ddof=1)
print('Standardabweichungen')
std
# Out:
# Standardabweichungen
# Nullrate a [ips]       0.031623
# Nullrate a+b [ips]     1.581139
# Sr a [ips]             0.051640
# Sr a+b [ips]          31.622777
# Am a [ips]            48.304589
# Am a+b [ips]           9.486833
# dtype: float64

# %% [markdown]
# ### Mittelwert und Standartabweichung
# Wie weiter oben ersichtlich sind $^{90}Sr$, sowie das Zerfallsprodukt $^{90}Y$ $\beta^{-}$-Strahler. Aus den Messwerten geht für den Eichstrahler $^{90}Sr$ eine momentane Aktivität von $190 \pm 31.6$ ips hervor. Dies liegt gut im Rahmen einer Abweichung vom Erwartungswert von $\pm$ 25% (tollerable Abweichung gemäß Dokumentation).
#
# Auffällig ist hier die leicht erhöhte Aktivität im Empfindlichkeitsbereich **a**. Erklären lässt sich das Verhalten mit der Annahme, dass das vorliegende Oberflächenkontaminationsmessgerät die Empfindlichkeitsbereiche **a** und **a+b** durch Filterung von Impulshöhen vornimmt. $\beta$-Strahlung bringt typischerweise im Vergleich zu $\alpha$-Strahlung je Event deutlich weniger Energie mit. Dennoch kann es passieren, dass ein $\beta$-Teilchen etwa räumlich günstig auf ein Zählgasmolekül trifft, dass der ausgelößte Impuls hoch genug ist, um im Messbereich **a** dennoch registriert zu werden.
#
# Für $^{241}Am$ mit einer mittleren Zählrate von $230 \pm 48,3$ ips ergibt sich gegenüber dem Erwartungswert von 189 ips eine Abweichung von $(82,2 \pm 14,3)$ %.

# %% [markdown]
# ### Unbekannte Proben

# %% [markdown]
# #### Einfluss des Abstandes zur Probe
# Drei unbekannte Proben sollen untersucht werden. Zur Untersuchung werden jeweils Messungen in beiden Modi durchgeführt (**a** und **a+b**).
#
# Um die Gültigkeit bzw. Auswirkung des Abstandsquadrat-Gesetzes zu überprüfen werden Messungen in Abständen von $(50 < d \leq 0)$ cm bei einer Intervallbreite von 10 cm.

# %%
print('Tabelle 2: Messwerte der unbekannten Proben bei einer Anfangsdistanz von 50 cm bis 0 cm (Kontakt).')
unkn1
# Out:
# Tabelle 2: Messwerte der unbekannten Proben bei einer Anfangsdistanz von 50 cm bis 0 cm (Kontakt).
#    Abstand [cm]  P1 a [ips]  P1 a+b [ips]  P2 a [ips]  P2 a+b [ips]  \
# 0          50.0         0.0             5         0.1             6
# 1          40.0         0.0             5         0.1             8
# 2          30.0         0.0             5         0.1            10
# 3          20.0         0.0             5         0.0            20
# 4          10.0         0.1             5         0.0            40
# 5           0.1        30.0            90         0.0           200
#
#    P3 a [ips]  P3 a+b [ips]
# 0         0.1             5
# 1         0.1             5
# 2         0.1             5
# 3         0.0             6
# 4         0.0             6
# 5         0.0             5

# %% [markdown]
# #### Strahlenarten der jeweiligen Proben
# Die Mittelwerte aus den Referenzwerten wurden bei Kontakt des Messgerätes mit den jeweiligen Eichstrahlern gemessen. Daher erfolgt ein Vergleich der Messwerte der Proben P1-P3 bei dem Abstand von 0 cm.
#
# Der Vergleich lässt darauf schließen, dass P1 Anteile von %\alpha$- und $\beta$-Strahlung aufweist, während der $\beta$-Anteil dominiert.
#
# Mit ausreichender Sicherheit lässt sich sagen, dass P2 ein reiner $\beta$-Strahler ist.
#
# Die Messwerte für P3 liegen nah an den Referenzwerten für die Nullrate. Es liegt also nahe, dass P3 kein strahlendes Isotop enthält.

# %%
# def funct_expo(r, lambd, I0):
	# return I0 * np.exp(-lambd*r)

def dist_law(r, I0):
	return I0 * (0.1**2 / r**2)

def solid_angle(r, I0, a, b):
	# a,b are the sides of a rectangle - the outer dimensions of the detector in our case
	return I0 * 4 * np.arctan((a * b) / (2 * r * np.sqrt(4 * r**2 + a**2 + b**2))) / (2 * np.pi)

# %%
# popt, pcov = curve_fit(funct_expo, unkn1["Abstand [cm]"], unkn1["P2 a+b [ips]"] - means[1], p0=(1, unkn1.iloc[5, 4]-means[1]))
# print(popt)

xarr = np.linspace(unkn1["Abstand [cm]"][5], unkn1["Abstand [cm]"][0], 50)
# print(solid_angle(0.001, 200))

# %% [markdown]
# #### Abstandgesetz
#
# Der folgende Plot zeigt den Verlauf der Zählrate bei wachsendem Abstand. Die Zählrate wurde um den Offset des Mittelwertes der Nullrate im Messbereich **a+b** korrigiert.
#
# Der gestrichelte Plot zeigt den Verlauf, wenn die Zählrate streng dem Gesetz des Abstandsquadrates folgte. Auffällig ist sofort, dass die Zählrate nicht wie erwartet mit $\frac{1}{r^2}$ abfällt. Bei näherer Überlegung erscheint das sinnvoll, da sowohl die Quelle, als auch die Detektorfläche real ausgedehnt - oder in anderen Worten nicht punktförmig - sind.
#
# Einen Ansatz üper den Raumwinkelanteil der Detektorfläche zeigt der gepunktete Plot. Die zugrunde liegende Überlegung ist hier, dass bei gegebenen Abständen die Detektorfläche jeweils einen Anteil $\omega$ des Raumwinkels $\Omega$ einnimmt. Bei sehr kleinen Abständen kann in guter Näherung ein durch den Detektor abgedeckter maximaler Raumwinkel von $\omega(r\rightarrow 0) = \frac{1}{2}\Omega$ angenommen werden. Wächst nun der Abstand zur Quelle, kann der durch die Detektorfläche eingenommene Raumwinkel relativ zur Quelle mit
# $$
# \begin{equation}
# \omega(r) = 4 \cdot \arctan{\left( \frac{a \cdot b}{2r\sqrt{4r^2+a^2+b^2}} \right)}
# \end{equation}
# $$
# angegeben werden. Die sich ergebende Zählrate ist demnach die maximale Zählrate $I(r\rightarrow 0) = I_0$ multipliziert mit dem Verhältnis des abgedeckten Raumwinkels zum Raumwinkel bei $r\rightarrow 0$.
# $$
# I(r) = I_0 \cdot \frac{2 \cdot \omega(r)}{\Omega}
# $$
# In der Tat passt der Ansatz des Raumwinkelanteils deutlich besser durch die Messdaten.

# %%
cm = 1/2.54 # inch zu cm
plt.style.use("default")
plt.style.use("dark_background")
fig, ax = plt.subplots(figsize=(35*cm, 35*cm * 9 / 16))

ax.scatter(unkn1["Abstand [cm]"], unkn1["P2 a+b [ips]"] - means[1], label="Messung")
ax.plot(xarr, dist_law(xarr, 194), linestyle='--', label="Ansatz Abstandsgesetz")
ax.plot(xarr, solid_angle(xarr, 194, 8, 20), linestyle=':', label="Ansatz Raumwinkelanteil")
# ax.plot(xarr, funct_expo(xarr, *popt), linestyle='--', label="Ansatz Exponential")

ax.set_title("P2 a+b")
# ax.set_ylim(ymin=0, ymax=200)
ax.legend()
ax.set_xlabel("Abstand / cm")
ax.set_ylabel("Zählrate / cps")
ax.grid(axis='both', alpha=.3)

# %% [markdown]
# Unten stehender Plot zeigt die übrigen Messdaten der Proben P1 bis P3 für die beiden Modi *a* und *a+b*.

# %%
fig, ax = plt.subplots(figsize=(35*cm, 35*cm * 9 / 16))

ax.scatter(unkn1["Abstand [cm]"], unkn1["P1 a [ips]"] - means[0], label=unkn1.columns[1])
ax.scatter(unkn1["Abstand [cm]"], unkn1["P1 a+b [ips]"] - means[1], label=unkn1.columns[2])
ax.scatter(unkn1["Abstand [cm]"], unkn1["P2 a [ips]"] - means[0], label=unkn1.columns[3])
ax.scatter(unkn1["Abstand [cm]"], unkn1["P3 a [ips]"] - means[0], label=unkn1.columns[5])
ax.scatter(unkn1["Abstand [cm]"], unkn1["P3 a+b [ips]"] - means[1], label=unkn1.columns[6])
ax.plot(xarr, solid_angle(xarr, unkn1["P1 a [ips]"].iloc[-1] - means[0], 8, 20), linestyle=':', label=unkn1.columns[1])
ax.plot(xarr, solid_angle(xarr, unkn1["P1 a+b [ips]"].iloc[-1] - means[0], 8, 20), linestyle=':', label=unkn1.columns[2])
ax.plot(xarr, solid_angle(xarr, unkn1["P2 a [ips]"].iloc[-1] - means[0], 8, 20), linestyle=':', label=unkn1.columns[3])
ax.plot(xarr, solid_angle(xarr, unkn1["P3 a [ips]"].iloc[-1] - means[0], 8, 20), linestyle=':', label=unkn1.columns[5])
ax.plot(xarr, solid_angle(xarr, unkn1["P3 a+b [ips]"].iloc[-1] - means[0], 8, 20), linestyle=':', label=unkn1.columns[6])
# ax.plot(xarr, funct_expo(xarr, *popt), linestyle='--', label="Ansatz Exponential")

ax.set_title("Messdaten der Proben P1, P2 und P3 jeweils in den Modi a und a+b")
# ax.set_ylim(ymin=0, ymax=90)
ax.legend()
ax.set_xlabel("Abstand / cm")
ax.set_ylabel("Zählrate / cps")
ax.grid(axis='both', alpha=.3)

# %%
print('Tabelle 3:Testkontamination seitlich gemessen')
unkn2
# Out:
# Tabelle 3:Testkontamination seitlich gemessen
#    Abgedeckte Probenfläche  P1 a [ips]  P1 a+b [ips]  P2 a [ips]  \
# 0                      0.0         0.1             5         0.1
# 1                      0.5         3.0            20         0.1
# 2                      1.0        30.0           100         0.1
#
#    P2 a+b [ips]  P3 a [ips]  P3 a+b [ips]
# 0             5         0.1             5
# 1            20         0.1             5
# 2           200         0.1             5

# %% [markdown]
# Um das Verhalten der gemessenen Zählraten bei Variation der überdeckten Probenfläche zu untersuchen, wurden sämtliche Proben bei sehr kleinen Abständen jeweils bei vollständig überdeckter, halb überdeckter und gänzlich freiliegender Probenfläche untersucht.
#
#         ┌────────────────┐                      ┌────────────────┐                   ┌────────────────┐
#         │                │                      │                │                   │                │
#         │                │     xxxx             │              ..│xx                 │      ....      │
#         │                │   xx    xx           │            ..  │  xx               │    ..    ..    │
#         │                │  x        x          │           .    │    x              │   .        .   │
#         │    Detektor    │ x  Probe   x         │          .     │     x             │  .          .  │
#         │                │  x        x          │           .    │    x              │   .        .   │
#         │                │   xx    xx           │            ..  │  xx               │    ..    ..    │
#         │                │     xxxx             │              ..│xx                 │      ....      │
#         │                │                      │                │                   │                │
#         └────────────────┘                      └────────────────┘                   └────────────────┘
#                0.0          ────────────────►          0.5         ────────────────►      1.0
#
# Es ist zu erkennen, dass die Zählraten zwar wie zu erwarten steigen, jedoch nicht linear.

# %% [markdown]
# ## Fazit
#
# Mit guter Sicherheit lässt sich sagen, dass es sich bei Probe P3 um kein strahlendes Isotop handelt. Messtechnisch konnte selbst bei quasi-direktem Kontakt zur Probe kein Unterschied zur Nullrate festgestellt werden.
#
# Die beiden Proben P1 und P3 jedoch äußern sich durch deutlich messbare Aktivität. P1 hat Anteile eines $\alpha$- und $\beta$-Strahlers. P2 scheint ein reiner $\beta$-Strahler zu sein. Da jedoch lediglich ionisierende Events gezählt werden kann keine Aussage über die vorliegenden Isotope getroffen werden.
